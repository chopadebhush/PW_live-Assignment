# %% [markdown]
# #### 2. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.
#
# Dataset Description:
#
# Lung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant
# challenges in early detection and effective treatment. To aid in the global effort to understand and combat this
# disease, we are excited to introduce our comprehensive Lung Cancer Dataset.
#
# Link: Lung Cancer

# %%
# Import necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Import the data in notebook

# %%
df =pd.read_csv("dataset.csv")
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# 0                    2                      2           1          NO
# 1                    1                      2           2          NO
# 2                    2                      1           1         YES
# 3                    1                      2           2         YES
# 4                    1                      1           2          NO

# %%
df.shape
# Out:
# (3000, 16)

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
#  15  LUNG_CANCER            3000 non-null   object
# dtypes: int64(14), object(2)
# memory usage: 375.1+ KB

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# min           1.000000     1.000000     1.000000     1.000000
# 25%           1.000000     1.000000     1.000000     1.000000
# 50%           2.000000     1.000000     2.000000     1.000000
# 75%           2.000000     2.000000     2.000000     2.000000
# max           2.000000     2.000000     2.000000     2.000000
#
#        ALCOHOL_CONSUMING     COUGHING  SHORTNESS_OF_BREATH  \
# count        3000.000000  3000.000000          3000.000000
# mean            1.491333     1.510667             1.488000
# std             0.500008     0.499970             0.499939
# min             1.000000     1.000000             1.000000
# 25%             1.000000     1.000000             1.000000
# 50%             1.000000     2.000000             1.000000
# 75%             2.000000     2.000000             2.000000
# max             2.000000     2.000000             2.000000
#
#        SWALLOWING_DIFFICULTY   CHEST_PAIN
# count            3000.000000  3000.000000
# mean                1.489667     1.498667
# std                 0.499977     0.500082
# min                 1.000000     1.000000
# 25%                 1.000000     1.000000
# 50%                 1.000000     1.000000
# 75%                 2.000000     2.000000
# max                 2.000000     2.000000

# %%
sns.histplot(data=df,x="AGE",hue="LUNG_CANCER")
plt.xlabel("Age")
plt.ylabel("freq")
plt.title("Distrubution of Age")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
fig,ax = plt.subplots(1,3,figsize=(20,6))
sns.distplot(df['AGE'],ax=ax[0])
sns.histplot(data =df,x='AGE',ax=ax[1],hue='LUNG_CANCER',kde=True)
sns.boxplot(x=df['LUNG_CANCER'],y=df['AGE'],ax=ax[2])
plt.suptitle("Visualizing AGE column",size=20)
plt.show()

# %% [markdown]
# #### Observaton and insight
#
# 1. I observed that the age feature follows a normal distribution and the Men are at a higher risk of developing lung cancer

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=df,x="GENDER")
plt.title("Count of Male and female")
plt.show()

# %% [markdown]
# ####  observation and Insight
#
# 1. there are 1500 male in data
# 2. there are nearly 1400 female

# %%
sns.countplot(data=df ,x="GENDER",hue="LUNG_CANCER")
plt.title("Lung cancer with respect to Gender")
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. there are 750 male has lung cancer
# 2. there are 770 female has lung cancer

# %%
df_lung_cancer =df.LUNG_CANCER.value_counts()
df_lung_cancer
# Out:
# LUNG_CANCER
# YES    1518
# NO     1482
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
df_lung_cancer.plot.pie(x=df_lung_cancer ,labels=df_lung_cancer.index,autopct ="%1.1f%%")
plt.title("Lung cancer %")
plt.show()

# %% [markdown]
# ####  Observation and Insight
#
# 1. 50.6% people has lung cancer.
# 2. 49.4% people has lung cancer.

# %%
sns.set_style('darkgrid')
fig1, ax1 = plt.subplots(figsize=(10,8))
colors = ['brown', 'pink', 'purple', 'orange']
df.groupby('GENDER')['SMOKING'].sum().nlargest(4).sort_values(ascending=False).plot(kind='bar', color=colors, ax=ax1)
plt.xlabel('Gender')
plt.ylabel('SMOKING')
plt.title('LUNG_CANCER')
plt.legend()
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. As Per the observation smoking is affecting on both Female and male Gender

# %%
#Who has a higher chance of getting Lung Cancer
df_lung_cancer_counter = df.groupby("GENDER")["LUNG_CANCER"].value_counts().unstack()
df_lung_cancer_counter
# Out:
# LUNG_CANCER   NO  YES
# GENDER
# F            722  764
# M            760  754

# %%
fig,ax =plt.subplots(1,2,figsize= (12,6))
ax[0].pie(df_lung_cancer_counter.iloc[0],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[0].set_title('Lung Cancer Distribution Among Females')

ax[1].pie(df_lung_cancer_counter.iloc[1],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[1].set_title('Lung Cancer Distribution Among Male')

plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. As per the observation both F & M can causes Lung Cancer.

# %%
#Does smoking causes Lung Cancer
df_smoking_causes_lung_cancer = df.groupby("SMOKING")["LUNG_CANCER"].value_counts().unstack()

# %%
df_smoking_causes_lung_cancer
# Out:
# LUNG_CANCER   NO  YES
# SMOKING
# 1            765  762
# 2            717  756

# %%
fig,ax =plt.subplots(1,2,figsize= (12,6))
ax[0].pie(df_smoking_causes_lung_cancer.iloc[0],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[0].set_title('Lung Cancer Distribution Among non-Smokers')

ax[1].pie(df_smoking_causes_lung_cancer.iloc[1],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[1].set_title('Lung Cancer Distribution Among Smokers')

plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. Yes Smoking Causes Lung Cancer.

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# 0                    2                      2           1          NO
# 1                    1                      2           2          NO
# 2                    2                      1           1         YES
# 3                    1                      2           2         YES
# 4                    1                      1           2          NO

# %%
df_short_breath_cancer =df.groupby("SHORTNESS_OF_BREATH")["LUNG_CANCER"].value_counts().unstack()

# %%
df_short_breath_cancer
# Out:
# LUNG_CANCER           NO  YES
# SHORTNESS_OF_BREATH
# 1                    757  779
# 2                    725  739

# %%
fig,ax =plt.subplots(1,2,figsize=(10,8))
ax[0].pie(x=df_short_breath_cancer.iloc[0],labels=["Yes","No"],autopct="%1.1f%%")
ax[1].pie(x=df_short_breath_cancer.iloc[1],labels=["Yes","No"],autopct="%1.1f%%")

plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. yes short breathness can causes cancer

# %%
plt.figure(figsize=(12,7))
mean_of_age = df.groupby(["LUNG_CANCER"])["AGE"].count().reset_index()

ax =sns.barplot(x="LUNG_CANCER",y="AGE",data=mean_of_age,errwidth=0)
plt.title("Age vs Lung cancer")
bar_lables =[ax.bar_label(i) for i in ax.containers]
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. Lung cancer of No- Category count is 1482
# 2. Lung cancer of Yes- category count is 1518

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# 0                    2                      2           1          NO
# 1                    1                      2           2          NO
# 2                    2                      1           1         YES
# 3                    1                      2           2         YES
# 4                    1                      1           2          NO

# %%
for col in df.columns :
    df[col] =df[col].replace({1:"NO",2:"YES"})
    
df.head()
# Out:
#   GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0      M   65      NO             NO      NO           YES             YES
# 1      F   55      NO            YES     YES            NO              NO
# 2      F   78     YES            YES      NO            NO              NO
# 3      M   60     YES             NO      NO            NO             YES
# 4      F   80      NO             NO     YES            NO              NO
#
#   FATIGUE ALLERGY WHEEZING ALCOHOL_CONSUMING COUGHING SHORTNESS_OF_BREATH  \
# 0      NO     YES      YES               YES      YES                 YES
# 1     YES     YES      YES                NO       NO                  NO
# 2     YES      NO      YES                NO       NO                 YES
# 3      NO     YES       NO                NO      YES                  NO
# 4     YES      NO      YES                NO       NO                  NO
#
#   SWALLOWING_DIFFICULTY CHEST_PAIN LUNG_CANCER
# 0                   YES         NO          NO
# 1                   YES        YES          NO
# 2                    NO         NO         YES
# 3                   YES        YES         YES
# 4                    NO        YES          NO

# %%
# Smokers count
plt.figure(figsize=(10,10))
ax =sns.countplot(x="SMOKING", data=df)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. As compare to smokers non-smoker is more count in data.

# %%
# ANXIETY count
plt.figure(figsize=(10,10))
ax =sns.countplot(x="ANXIETY", data=df,hue="LUNG_CANCER")

for i in ax.containers:
    ax.bar_label(i)

plt.legend(["Does not have cancer","Has cancer"])
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. if anxiety is No or yes person is might be lung cancer because less differance between counts.

# %%
# YELLOW_FINGERS count
plt.figure(figsize=(10,10))
ax =sns.countplot(x="YELLOW_FINGERS", data=df,hue="LUNG_CANCER")

for i in ax.containers:
    ax.bar_label(i)

plt.legend(["Does not have cancer","Has cancer"])
plt.show()

# %% [markdown]
# #### Observation and Insights
#
# 1.  If yellow fingure is NO we cant find there is lung cancer or not there was less differance in count.
#
# 2.  If yellow fingure is Yes there might be lung cancer due to feature Yellow fingure.

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
columns =df[['PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
       'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN']]

fig,ax =plt.subplots(nrows=10 ,ncols=1,figsize=(20,80))
fig.subplots_adjust(hspace=0.5)

for i,col in enumerate(columns):
    sns.countplot(x=col ,data=df,ax=ax[i],hue="LUNG_CANCER")
    
    ax[i].set_title(col)
    
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. After plotting multiple countplots for the different features, we can see that most surveyors said yes to having symptoms such as yellow fingers, coughing, fatigue, shortness of breath and chest pain meaning these are the primary/more crucial symptoms that people should look out for as they may be at risk of having cancer.
